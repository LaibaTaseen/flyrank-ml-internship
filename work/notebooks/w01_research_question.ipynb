# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LaibaTaseen/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/LaibaTaseen/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 120 (delta 36), reused 94 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 1.84 MiB | 14.08 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# %cd flyrank-ml-internship
# !ls data/raw
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship
# content_refresh_anonymized.csv

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# I selected the Refresh / Content Opportunity Scoring lane because I think it solves a practical problem. Instead of checking every page manually, machine learning can help identify which pages should be reviewed first based on their performance. The starter dataset includes useful information such as search performance, engagement, and content metrics, making it a good choice for this project. I chose this lane because it will help me learn how to use machine learning to support real-world content optimization and decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Decision: Decide which content pages should be reviewed first for refresh or improvement.
#
# Action: Review the highest-ranked pages and update, expand, improve, or monitor them based on their performance and opportunity.
#
# Cost of a wrong call: If a page is incorrectly recommended, time and effort may be wasted reviewing a page that doesn't need changes. If an important page is missed, it may continue losing traffic and valuable improvement opportunities could be overlooked.
#
# Why ML can help: Machine learning can analyze multiple content and performance signals at the same time, making it easier to identify pages that deserve attention. This helps prioritize pages more efficiently than checking every page manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
#
# The starter dataset contains 30,000 rows and 44 columns, providing a large amount of information for analysis. The average number of 90-day impressions is 5,200.37, the average number of 90-day sessions is 37.07, and the average content age is 256.17 days. These statistics show that the dataset contains meaningful content performance and engagement information, making it suitable for identifying pages that should be prioritized for content refresh and optimization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df.head()

# Number of rows and columns
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# Display column names
print("\nColumns:")
print(df.columns.tolist())

# Summary statistics
print(f"Average 90-day impressions: {df['impressions_90d'].mean():.2f}")
print(f"Average 90-day sessions: {df['sessions_90d'].mean():.2f}")
print(f"Average content age (days): {df['content_age_days'].mean():.2f}")
# Out:
# Number of rows: 30000
# Number of columns: 44
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# Average 90-day impressions: 5200.37
# Average 90-day sessions: 37.07
# Average content age (days): 256.17

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# At this stage, I cannot claim that the machine learning model will always make the correct recommendation. The goal of this project is to support decision-making, not replace human judgment. The model's performance will depend on the quality of the data, feature selection, and further evaluation. Any recommendations should be reviewed before taking action.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
#
#
# ✓ Every section above is filled — markdown thinking and the code that backs it.
#
# ✓ The notebook runs top to bottom with no errors (Runtime → Run all).
#
# ✓ No client names, URLs, or private queries anywhere.
#
# ✓ My claims use careful words: observed, measured, directional, decision-support.
#
# ✓ Committed to my repo under work/notebooks/ — then submit my repo URL on the card.
